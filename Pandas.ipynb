# %% [markdown]
# # Load Data
# Pandas dapat membaca berbagai jenis file seperti csv, excel, json, dll..), disini kita akan menggunakan jenis file csv.
# untuk *loading dataset*, pandas menggunakan fungsi "**pd.read_csv('*file_directory*')**" yang di-*assign* kedalam variabel df.

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\3139678956.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# ...

# %% [markdown]
# ## Menampilkan Data
# Pandas menampilkan data dalam bentuk **DataFrame** alias tabel yang terdiri atas baris dan kolom. ada beberapa cara untuk menampilkan data di pandas, yaitu :
# 1. dengan menjalankan kolom kode berisi nama variabel (dalam contoh ini adalah **df**), akan menampilkan 5 data paling atas dan 5 data paling bawah.
# 2. dengan menambahkan method .head(), contoh "**df.head()**" secara *default* akan menampilkan 5 data paling atas.
# 3. dengan menambahkan method .tail(), contoh "**df.tail()**" secara *default* akan menampikan 5 data paling bawah.
#
# baik method **.head()** atau **.tail()**, kita dapat menentukan jumlah baris yang ingin ditampilkan, contoh: "**df.head(10)** akan menampikan 10 baris paling atas dari data.

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %% [markdown]
# ## Memeriksa shape data
# Kita perlu mengetahui seberapa besar data yang akan dikerjakan, untuk mengetahuinya pandas menyediakan atribut ".shape", contoh: "**df.shape**" akan menampilkan output (88883, 85) yang dibaca 88883 baris dengan 85 kolom. Atribut "**.shape**" hanya memberikan informasi mengenai jumlah baris dan kolom.

# %%
df.shape
# Out:
# (88883, 85)

# %% [markdown]
# Selain atribut "**.shape**" yang menampilkan jumlah baris dan kolom, pandas juga menyediakan fungsi untuk memeriksa ukuran dataset beserta tipe data dari masing-masing kolomnya, yaitu "**.info()**", contoh: "**df.info()**" akan menghasilkan output sebagai berikut:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %% [markdown]
# Secara default tipe data di pandas adalah sebagai berikut:
# 1. Object = string
# 2. int64 = integer
# 3. float64 = decimal

# %% [markdown]
# ## Setting Display
# secara *default* pandas hanya akan menampikan 25 kolom dengan 10 baris. Namun kita dapat menampilkan seluruh baris dan kolom pada dataset, dengan menggunakan funngsi:
# 1. pd.set_option('display.max_columns', 85) #akan menampilkan maksimal 85 kolom.
# 2. pd.set_option('display.max_rows', 85) #akan menampilkan maskimal 85 baris.
#
# yang harus diperhatikan dalam menentukan *max_rows* adalah **seberapa besar dataset yang kita miliki**, dalam contoh ini ada 88883 baris (ga mungkin kita akan menampilkan semua barisnya).

# %% [markdown]
# # DataFrame dan Series
# Pada dasarnya **DataFrame** adalah sebuah array 2-dimensi (*2-dimension array*) atau sebuah tabel. Tabel memiliki baris yang mewakili record (*objek interest*) dan kolom (*feature*) yang mewakili karateristik sebuah record.
#
# Secara default (*standard*) python menghandle data tabel dalam bentuk *dict*, dan Pandas DataFrame dibangun dari *dict* seperti berikut:

# %%
# Sample dictionary with 10 rows (entries)
sample_data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily', 'Frank', 'Grace', 'Henry', 'Isabella', 'Jack'],
    'Age': [25, 30, 22, 38, 28, 42, 35, 21, 27, 33],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Toronto', 'London', 'Paris', 'Berlin', 'Tokyo', 'Sydney', 'Rome'],
    'Email': ['alice@example.com', 'bob@example.com','charlie@example.com', 'david@example.com', 'emily@example.com', 'frank@example.com',
              ' grace@example.com', 'henry@example.com','isabella@example.com','jack@example.com']
}

# %%
# Importing library pandas
import pandas as pd

# %%
# create Dataframe from sample_data
df = pd.DataFrame(sample_data)

# %%
# Pandas DataFrame
df
# Out:
#        Name  Age         City                 Email
# 0     Alice   25     New York     alice@example.com
# 1       Bob   30  Los Angeles       bob@example.com
# 2   Charlie   22      Chicago   charlie@example.com
# 3     David   38      Toronto     david@example.com
# 4     Emily   28       London     emily@example.com
# 5     Frank   42        Paris     frank@example.com
# 6     Grace   35       Berlin     grace@example.com
# 7     Henry   21        Tokyo     henry@example.com
# 8  Isabella   27       Sydney  isabella@example.com
# 9      Jack   33         Rome      jack@example.com

# %%
# Standard python
sample_data
# Out:
# {'Name': ['Alice',
#   'Bob',
#   'Charlie',
#   'David',
#   'Emily',
#   'Frank',
#   'Grace',
#   'Henry',
#   'Isabella',
#   'Jack'],
#  'Age': [25, 30, 22, 38, 28, 42, 35, 21, 27, 33],
#  'City': ['New York',
#   'Los Angeles',
#   'Chicago',
#   'Toronto',
#   'London',
#   'Paris',
#   'Berlin',
#   'Tokyo',
#   'Sydney',
#   'Rome'],
#  'Email': ['alice@example.com',
#   'bob@example.com',
#   'charlie@example.com',
#   'david@example.com',
#   'emily@example.com',
#   'frank@example.com',
#   ' grace@example.com',
#   'henry@example.com',
#   'isabella@example.com',
#   'jack@example.com']}

# %% [markdown]
# Dataframe lebih mudah dibaca dibandingkan dengan standard python. hal ini dikarenakan dataframe menampilkan data dalam bentuk tabel seperti pada spreadsheet. selain itu dataframe memungkinkan kita untuk memilih satu atau lebih kolom ataupun baris.

# %% [markdown]
# ## Selecting rows or columns
# Untuk melakukannya kita memerlukan sebuah fungsi **.loc** dan **.iloc**, perbedaanya adalah kalo **.loc** kita dapat memilih berdasarkan *value* didalam tabel. Sementara **.iloc** kita harus menggunakan nomor index dari data yang diinginkan (**.iloc** itu singkatan **Integer location**).

# %%
# Selecting a single rows value
df.iloc[0]
# Out:
# Name                 Alice
# Age                     25
# City              New York
# Email    alice@example.com
# Name: 0, dtype: object

# %%
# Selecting multiple rows 
df.iloc[:3]
# Out:
#       Name  Age         City                Email
# 0    Alice   25     New York    alice@example.com
# 1      Bob   30  Los Angeles      bob@example.com
# 2  Charlie   22      Chicago  charlie@example.com

# %%
# Selecting multiple rows
df.loc[:3]
# Out:
#       Name  Age         City                Email
# 0    Alice   25     New York    alice@example.com
# 1      Bob   30  Los Angeles      bob@example.com
# 2  Charlie   22      Chicago  charlie@example.com
# 3    David   38      Toronto    david@example.com

# %%
# Selecting multiple random rows
df.iloc[[1, 5, 6, 8]]
# Out:
#        Name  Age         City                 Email
# 1       Bob   30  Los Angeles       bob@example.com
# 5     Frank   42        Paris     frank@example.com
# 6     Grace   35       Berlin     grace@example.com
# 8  Isabella   27       Sydney  isabella@example.com

# %%
# Selecting multiple random rows
df.loc[[1, 5, 6, 8]]
# Out:
#        Name  Age         City                 Email
# 1       Bob   30  Los Angeles       bob@example.com
# 5     Frank   42        Paris     frank@example.com
# 6     Grace   35       Berlin     grace@example.com
# 8  Isabella   27       Sydney  isabella@example.com

# %%
# Selecting multiple rows with only 2 columns (with .iloc)
df.iloc[0:3,[0,1]]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   22

# %%
# Selecting multiple rows with only 2 columns (with .loc)
df.loc[0:3,['Name', 'Age']]
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   22
# 3    David   38

# %%
# Selecting multiple spesific rows (with .iloc)
df.iloc[[1, 3, 5],[0,1]]
# Out:
#     Name  Age
# 1    Bob   30
# 3  David   38
# 5  Frank   42

# %%
# Selecting multiple spesific rows (with .loc)
df.loc[[1, 3, 5],['Name', 'Age']]
# Out:
#     Name  Age
# 1    Bob   30
# 3  David   38
# 5  Frank   42

# %% [markdown]
# Pada dasarnya memilih baris dan kolom pada dataframe baik menggunakan **.loc** ataupun **.iloc** sama seperti melakukan **slicing** pada **list**. perbedaanya ada pada :
# 1. **.loc**, kita dapat menggunakan *value*. contoh: df.loc[0:3,**['Name', 'Age']**], disini kita memilih kolom name dan age dengan meneruskan nama kolomnya pada baris kode dalam bentuk **list**. Sementara **.iloc**, kita harus menggunakan index untuk memilih kolom maupun baris. contoh: df.iloc[0:3, **[0,1]**], disini kita meneruskan index kolom name dan index kolom age dalam bentuk list juga.
# 2. slicing menggunakan **.loc** bersifat *inclusive* artinya index paling akhir akan ikut ditampilkan, Sementara pada **.iloc** memiliki sifat *exclusive* dimana index paling akhir tidak akan ikut ditampilkan.

# %%
# Selecting a column (cara 1)
df['Name']
# Out:
# 0       Alice
# 1         Bob
# 2     Charlie
# 3       David
# 4       Emily
# 5       Frank
# 6       Grace
# 7       Henry
# 8    Isabella
# 9        Jack
# Name: Name, dtype: object

# %%
# Selecting a column (cara 2)
df.Name
# Out:
# 0       Alice
# 1         Bob
# 2     Charlie
# 3       David
# 4       Emily
# 5       Frank
# 6       Grace
# 7       Henry
# 8    Isabella
# 9        Jack
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Kalo kita memilih 1 kolom saja, kita akan mendapatkan sebuah **Series**. Agar lebih mudah cukup bayangkan Series sebagai sebuah kolom, **Series = Kolom**

# %% [markdown]
# # Indexes
# Setting index, reset index, and using index

# %%
# Using email as index
df.set_index('Email')
# Out:
#                           Name  Age         City
# Email
# alice@example.com        Alice   25     New York
# bob@example.com            Bob   30  Los Angeles
# charlie@example.com    Charlie   22      Chicago
# david@example.com        David   38      Toronto
# emily@example.com        Emily   28       London
# frank@example.com        Frank   42        Paris
#  grace@example.com       Grace   35       Berlin
# henry@example.com        Henry   21        Tokyo
# isabella@example.com  Isabella   27       Sydney
# jack@example.com          Jack   33         Rome

# %%
# Making email as index (change the original dataset)
df.set_index('Email', inplace=True)

# %%
df
# Out:
#                           Name  Age         City
# Email
# alice@example.com        Alice   25     New York
# bob@example.com            Bob   30  Los Angeles
# charlie@example.com    Charlie   22      Chicago
# david@example.com        David   38      Toronto
# emily@example.com        Emily   28       London
# frank@example.com        Frank   42        Paris
#  grace@example.com       Grace   35       Berlin
# henry@example.com        Henry   21        Tokyo
# isabella@example.com  Isabella   27       Sydney
# jack@example.com          Jack   33         Rome

# %%
# Using new index
df.loc['alice@example.com']
# Out:
# Name       Alice
# Age           25
# City    New York
# Name: alice@example.com, dtype: object

# %%
# Using new index for spesific value
df.loc['alice@example.com', 'Age']
# Out:
# 25

# %% [markdown]
# ## Reset Index

# %%
# reset index to dataframe default
df.reset_index(inplace=True)

# %%
df
# Out:
#                   Email      Name  Age         City
# 0     alice@example.com     Alice   25     New York
# 1       bob@example.com       Bob   30  Los Angeles
# 2   charlie@example.com   Charlie   22      Chicago
# 3     david@example.com     David   38      Toronto
# 4     emily@example.com     Emily   28       London
# 5     frank@example.com     Frank   42        Paris
# 6     grace@example.com     Grace   35       Berlin
# 7     henry@example.com     Henry   21        Tokyo
# 8  isabella@example.com  Isabella   27       Sydney
# 9      jack@example.com      Jack   33         Rome

# %% [markdown]
# ## Setting index
# **Setting index**, dapat dilakukan dengan menggunakan perintah **df.set_index(*kolom yang diinginkan*)**.
# Pada dasarnya kita memilih kolom mana yang kita inginkan untuk menjadi index yang mewakili baris (*record*) pada dataset, yang harus diperhatikan adalah: index merupakan *identifier(id)*, yang artinya values (nilainya) harus unique. Terkadang kita perlu melakukan setting terhadap index untuk memudahkan kita menemukan baris spesifik menggunakan perintah **.loc**.
#
# Misalkan kita ingin memeriksa pertanyaan atas suatu jawaban, contohnya adalah jawaban atas kolom **Hobbyist**. Kita dapat mendapat pertanyaan terkait kolom **Hobbyist** dengan melihat skema data, tahapannya:
# 1. Load dataset
# 2. Setting kolom **Column** menjadi index pada skema_data.
# 3. Gunakan **.loc** untuk mencari baris yang memiliki index **Hobbyist**

# %%
# Load dataset
data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
skema_data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019/survey_results_schema.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\269176283.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\269176283.py:3: SyntaxWarning: invalid escape sequence '\D'
#   skema_data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019/survey_results_schema.csv')

# %%
# Setting max rows and columns
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
data.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
skema_data
# Out:
#                     Column                                       QuestionText
# 0               Respondent  Randomized respondent ID number (not in order ...
# 1               MainBranch  Which of the following options best describes ...
# 2                 Hobbyist                            Do you code as a hobby?
# 3              OpenSourcer        How often do you contribute to open source?
# 4               OpenSource  How do you feel about the quality of open sour...
# 5               Employment  Which of the following best describes your cur...
# 6                  Country          In which country do you currently reside?
# 7                  Student  Are you currently enrolled in a formal, degree...
# 8                  EdLevel  Which of the following best describes the high...
# 9           UndergradMajor  What was your main or most important field of ...
# 10                EduOther  Which of the following types of non-degree edu...
# ...

# %%
# Setting index
skema_data.set_index('Column', inplace=True)

# %%
# Looking for the adressed row
skema_data.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %% [markdown]
# Setting index pada dataset skema_data diatas, akan sangat berguna ketika baris yang diinginkan terlalu panjang sehingga pandas secara otomati melakukan *Concatenation* / values diakhiri dengan "...", contohnya kalo kita tidak dapat mengetahui apa pertanyaan untuk kolom "**OpenSource**" karena terlalu panjang sehingga python melakukan *Concatenation*, untuk mengetahuinya adalah:
# 1. pastikan setting index telah dilakukan.
# 2. gunakan **.loc** untuk menampilkan baris dengan *index rows* beserta *index columns*.
#
# karena pada skema_data telah dilakukan setting index, maka kita cukup menuliskan baris kode sebagai berikut:

# %%
skema_data.loc['OpenSource', 'QuestionText']
# Out:
# 'How do you feel about the quality of open source software (OSS)?'

# %% [markdown]
# Hal yang harus diperhatikan dalam melakukan indexing:
# 1. dalam beberapa dataset, biasanya terjadi double index (index default pandas dengan index bawaan dataset). kita hanya harus index mana yang akan dipilih.
# 2. setting index harus disesuai dengan konteks tentang apa yang henda dilakukan, misalnya pada contoh diatas kita ingin mengetahui pertanyaan atas jawaban pada suatu kolom.
# 3. Jika sudah terlanjut melakukan setting index, kita dapat mengembalikannya ke awal dengan menggunakan "**.reset_index('Nama variabel')**"
# 4. Pandas tidak akan menyimpan semua perubahan dari setting_index atau reset_index, jika tidak diikuti dengan "**inplace=True**". cth: **df.set_index('Name', inplace=True)**

# %% [markdown]
# # Filtering
# **Filtering** pada dasarnya memisahkan data berdasarkan suatu kondisi (*conditional*). Ini merupakan salah satu teknik analisis data, dimana kita ingin menampilkan data yang hanya memenuhi kondisi yang kita tentukan.

# %%
people = {
    'first':['corey', 'jane', 'jhon'],
    'last':['schafer', 'doe', 'doe'],
    'email':['coreymschafer@example.com', 'janedoe@example.com', 'jhondoe@example.com']
    
}

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(people)

# %%
df1
# Out:
#    first     last                      email
# 0  corey  schafer  coreymschafer@example.com
# 1   jane      doe        janedoe@example.com
# 2   jhon      doe        jhondoe@example.com

# %%
# Showing every record where the last name is Doe
filt = df1['last'] == 'doe'
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: last, dtype: bool

# %%
df1[filt]
# Out:
#   first last                email
# 1  jane  doe  janedoe@example.com
# 2  jhon  doe  jhondoe@example.com

# %% [markdown]
# Dalam melakukan filtering kita menggunakan tanda logika seperti: '==', '>', '<', '>=', '<=', tujuannya adalah untuk membuat kondisi (*conditional*) yang menjadi *thumb of rule*. Pada contoh diatas kita membuat filter dimana baris yang akan ditampilkan harus berisi 'doe'pada kolom last, dan memasukkannya kedalam variabel filt, namun pandas menampilkan nilai boolean (True/False). <br>
# nilai boolean (True/False) akan menjadi dasar bagi dataframe untuk memilih baris mana yang harus ditampilkan, jika nilai boolean = True maka baris tersebut, sedangkan Flase baris tidak akan ditampilkan.

# %%
df1.loc[filt, 'email']
# Out:
# 1    janedoe@example.com
# 2    jhondoe@example.com
# Name: email, dtype: object

# %% [markdown]
# Ada beberapa cara ntuk menampilkan hasil filtering dalam bentuk dataframe, yaitu:
# 1. menulis variabel dataset yang diikuti dengan baris kode filter, contoh: **df1[df1['last']=='doe']**.
# 2. menulis variabel dataset yang diikuti dengan variabel yang berisi baris kode filter, contoh: **df1[filt]**.
# 3. menggunakan "**.loc**", contoh: **df.loc[filt]**

# %% [markdown]
# Kita dapat menggunakan lebih dari 1 filter, caranya adalah dengan menambahkan 'AND(&)' dan 'OR(|)' diantara masing-masing filter (kondisi / *conditional*).

# %%
# Multi filter using OR (|)
filt= (df1['last'] == 'schafer') | (df1['first'] == 'jhon')

# %%
df1.loc[filt]
# Out:
#    first     last                      email
# 0  corey  schafer  coreymschafer@example.com
# 2   jhon      doe        jhondoe@example.com

# %% [markdown]
# contoh kode:
# > filt = (df1['last'] == 'schafer') | (df1['first'] == 'jhon')
#
# Pada variabel filt diatas hanya akan menampilkan semua baris yang kolom awalnya corey atau yang kolom akhirnya jhon. hal ini dikarenakan sifat logika OR, dimana baris yang memenuhi minimal salah satu dari kedua kondisi filter akan ditampilkan.

# %%
# Multi filter using AND (&)
filt = (df1['last'] == 'doe') & (df1['first'] == 'jhon')

# %%
df1.loc[filt]
# Out:
#   first last                email
# 2  jhon  doe  jhondoe@example.com

# %% [markdown]
# contoh kode:
# > filt = (df1['last'] == 'doe') & (df1['first'] == 'jhon')
#
# pada variabel filt diatas hanya akan menampilkan semua baris yang kolom awalnya jhon dan kolom akhirnya doe. hal ini disebebkan karena **sifat logika AND** yang **mengharuskan kedua kondisi terpenuhi**, sehingga semua baris yang tidak memenuhi kedua kondisi/kriteria tidak akan ditampilkan.

# %%
# Multi filter using AND (&)
filt = (df1['last'] == 'doe') & (df1['first'] == 'jhon')
df1.loc[~filt]
# Out:
#    first     last                      email
# 0  corey  schafer  coreymschafer@example.com
# 1   jane      doe        janedoe@example.com

# %% [markdown]
# **tanda negasi (~)** pada teknik filtering di pandas merupakan tanda NOT yang akan menampilkan baris nilai yang berkebalikan dengan kriteria filter. Pada kode diatas seharusnya hanya menampilkan baris yang memenuhi kedua kriteria filter, namun dikarenakan tanda negasi (~), hasil yang ditampilkan adalah nilai yang tidak memenuhi kedua kriteria filter.
#
# tanda negasi (~) dapat digunakan untuk membalik filter baik menggunakan logika AND ataupun logika OR

# %% [markdown]
# ## Contoh Filtering pada dataset
# 1. tampilkan data dimana hanya ada baris dengan penghasilan diatas 70000.
# 2. tampilkan yang hanya terdiri atas negara US, UK, Canada, India, dan German.
# 3. tampilkan data dimana hanya ada baris dengan penghasilan diatas 70000 untuk negara US, UK, Canada, India, dan German dengan bahasa pemrograman salah satunya python.

# %%
# Load dataset
data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019/survey_results_public.csv', index_col='Respondent')
skema_data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019/survey_results_schema.csv')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\1600446828.py:2: SyntaxWarning: invalid escape sequence '\D'
#   data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019/survey_results_public.csv', index_col='Respondent')
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\1600446828.py:3: SyntaxWarning: invalid escape sequence '\D'
#   skema_data = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019/survey_results_schema.csv')

# %% [markdown]
# 1. menampilkan data dimana hanya ada baris dengan penghasilan diatas 70000. caranya:
#    - buat variabel filt yang berisi kondisi/kriteria untuk filtering
#    - gunakan "**.loc**" untuk menampilkan data yang telah difilter

# %%
# Create filter
filt = data['ConvertedComp'] > 70000

# %%
data.loc[filt, ['ConvertedComp']]
# Out:
#             ConvertedComp
# Respondent
# 6                366420.0
# 9                 95179.0
# 13                90000.0
# 16               455352.0
# 22               103000.0
# ...                   ...
# 88876            180000.0
# 88877           2000000.0
# 88878            130000.0
# 88879             82488.0
# 88882            588012.0
#
# [22289 rows x 1 columns]

# %% [markdown]
# 2. menampilkan yang hanya terdiri atas negara US, UK, Canada, India, dan German. caranya:
#    - buat variabel yang berisi sebuah list dari nama negara yang ingin ditampilkan.
#    - buat variabel filt untuk menampung kondisi/kriteria yang diinginkan, dalam hal ini dikarenakan kriteria yang diinginkan terdiri atas beberapa nilai dengan tipe data string/object, maka kita dapat menggunakan salah satu fungsi bawaan pandas dataframe, yaitu "**.isin()**" setelah memilih kolom yang dinginkan.
#    - gunakan "**.loc**" untuk menerapkan filter<br>
#
# >**.isin()** berfungsi untuk memeriksa keberadaan elemen DataFrame atau Series yang ada didalam kumpulan nilai yang kita tentukan/sediakan.

# %%
# Create a list for 
countries = ['United States', 'United Kingdom', 'India', 'Canada', 'Germany']
filt = (data['Country'].isin(countries))

# %%
data.loc[filt, ['Country']]
# Out:
#                    Country
# Respondent
# 1           United Kingdom
# 4            United States
# 6                   Canada
# 8                    India
# 10                   India
# ...                    ...
# 85642        United States
# 85961       United Kingdom
# 86012                India
# 88282        United States
# 88377               Canada
#
# [45008 rows x 1 columns]

# %%
filt = data.LanguageWorkedWith

# %% [markdown]
# 3. menampilkan data dimana hanya ada baris dengan penghasilan diatas 70000 untuk negara US, UK, Canada, India, dan German dengan bahasa pemrograman salah satunya python. tahapannya:
#    - buat variabel filt yang berisi semua kondisi/kriteria untuk masing-masing kolom, pastikan setiap kondisi berada tanda kurung (*parentheses*).
#    - tampilkan data dengan "**.loc**", disini penggunaan fungsi .loc sangat membantu karena kita dapat secara bersamaan melakukan seleksi atas kolom yang diinginkan.
#
# hal yang harus diperhatikan:
# - dalam melakukan filter terhadap kolom **LanguageWorkedWith**, kita menggunakan salah satu fungsi string yaitu **.contains**. hal ini perlu dilakukan karena tipe values yang disimpan pada kolom ini merupkana object/string, serta karena setiap responden memiliki kemampuan bahasa pemrograman lebih dari satu maka kita tidak dapat menggunakan fungsi **.isin()** karena tipe data bukan nominal/label seperti pada kolom Country.
# > (data['LanguageWorkedWith'].str.contains('Python', na=False)).
# - **.str** diperlukan untuk memberi tahu python bahwa fungsi yang akan dipakai berikutnya merupakan salah satu fungsi string python (bukan fungsi bawaan pandas).
# - **'Python'** merupakan teks yang kita tuju, ini memberi tahu python teks yang harus ada (*search pattern*) pada setiap baris pada kolom **LanguageWorkedWith**
# - **na=False**, tujuannya untuk mengabaikan baris yang Nan sehingga tidak menimbulkan error

# %%
filt = (data['ConvertedComp']>70000) & (data['Country'].isin(countries)) & (data['LanguageWorkedWith'].str.contains('Python', na=False))

# %%
data.loc[filt, ['ConvertedComp', 'Country', 'LanguageWorkedWith']]
# Out:
#             ConvertedComp        Country  \
# Respondent
# 22               103000.0  United States
# 26               114000.0  United States
# 32              1100000.0  United States
# 45               175000.0  United States
# 60               107000.0  United States
# ...                   ...            ...
# 88839             95000.0  United States
# 88861             97389.0        Germany
# 88873             72522.0         Canada
# 88874           2000000.0  United States
# 88876            180000.0  United States
#
#                                            LanguageWorkedWith
# Respondent
# 22          Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 26          Bash/Shell/PowerShell;C++;C#;HTML/CSS;JavaScri...
# 32          Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 45                                                     Python
# 60          Bash/Shell/PowerShell;Go;JavaScript;PHP;Python...
# ...                                                       ...
# ...

# %% [markdown]
# # Update Values
# Update values atau memperbaharui nilai merupakan salah satu teknik yang harus dikuasai dalam melakukan data analisis terutama pada tahapan data cleaning. Pada tahapan pembersihan data (data cleaning) terkadang mengharuskan kita untuk memperbaiki data seperti:
# - Mengganti nilai
# - Menyamakan font
# - Memperbaiki typo (salah ketik)
# - dll..<br>
#
# Perbaikan dilakukan dengan mengganti nilai-nilai diatas dengan yang lebih sesuai</n>

# %%
# Sample data
data = {
    "Buah (items)": ["Apel", "Pisang", "Jeruk", "Anggur"],
    "Hrga (price)": [5000, 3000, 7000, 10000],
    "Stok (quantity)": [10, 20, 15, 8],
    "Supplier":["Lembang", "Garut", "Pangalengan", "Bogor"]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#   Buah (items)  Hrga (price)  Stok (quantity)     Supplier
# 0         Apel          5000               10      Lembang
# 1       Pisang          3000               20        Garut
# 2        Jeruk          7000               15  Pangalengan
# 3       Anggur         10000                8        Bogor

# %% [markdown]
# Salah penulisan nama kolom, pada contoh diatas terdapat kesalahan penulisan nama kolom **Hrga** yang seharusnya adalah **Harga**. Untuk memperbaikinya kita memerlukan fungsi bawaan pandas yaitu **.columns** diikuti dengan sebuah list berisi nama-nama kolom. berikut adalah contoh kodenya:

# %%
df.columns = ['Buah (items)', 'Harga (price)', 'Stok (quantity)', 'Supplier']
df
# Out:
#   Buah (items)  Harga (price)  Stok (quantity)     Supplier
# 0         Apel           5000               10      Lembang
# 1       Pisang           3000               20        Garut
# 2        Jeruk           7000               15  Pangalengan
# 3       Anggur          10000                8        Bogor

# %% [markdown]
# Ternyata setelah penulisan nama kolom yang diinginkan adalah uppercase. Untuk membuat nama kolom menjadi uppercase, kita dapat menggunakan sebuah _**list comprehension**_ dengan method string yaitu **.upper**, berikut adalah contoh kodenya:

# %%
df.columns = [x.upper() for x in df.columns]
df
# Out:
#   BUAH (ITEMS)  HARGA (PRICE)  STOK (QUANTITY)     SUPPLIER
# 0         Apel           5000               10      Lembang
# 1       Pisang           3000               20        Garut
# 2        Jeruk           7000               15  Pangalengan
# 3       Anggur          10000                8        Bogor

# %% [markdown]
# Selain **.upper** kita juga dapat menggunakan semua string method, seperti ''**.lower(); .capitalize(); dll**'' . Berikut adalah contoh baris kode menggunakan **.lower()**:

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#   buah (items)  harga (price)  stok (quantity)     supplier
# 0         Apel           5000               10      Lembang
# 1       Pisang           3000               20        Garut
# 2        Jeruk           7000               15  Pangalengan
# 3       Anggur          10000                8        Bogor

# %% [markdown]
# Setelah dipikir-pikir ternyata nama kolom dengan penulisan lower case lah yang dipilih, namun dikarenakan nama kolom terdapat spasi yang menyebabkan *dot notation* menjadi tidak berfungsi. Untuk mengatasi hal ini kita memutuskan untuk mengganti "spasi" dengan "_", untuk melakukannya kita harus menggunakan fungsi **.str** yang diikuti dengan **.replace()**. Berikut adalah contoh kodenya:

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#   buah_(items)  harga_(price)  stok_(quantity)     supplier
# 0         Apel           5000               10      Lembang
# 1       Pisang           3000               20        Garut
# 2        Jeruk           7000               15  Pangalengan
# 3       Anggur          10000                8        Bogor

# %% [markdown]
# Selain teknik-teknik diatas, ada sebuah teknik yaitu **.rename** yang dapat digunakan untuk mengubah nama kolom, penjelasan lebih lengkap dapat pada documentation pandas.

# %% [markdown]
# ## Updating row's value
# untuk memperbaiki nilai pada baris dapat dilakukan dengan mencari baris yang ingin diubah terlebih dahulu, caranya ada 2 yaitu :
# 1. dengan teknik indexing seperti **.loc** atau **.iloc**
# 2. dengan teknik filtering

# %% [markdown]
# ### __1. Teknik indexing seperti **.loc** atau **.iloc**__
# Misalkan pada contoh data diatas, kita ingin memperbaharui harga Pisang menjadi 4000 dengan tenik indexing, yang menggunakan **.loc** dan meneruskan index baris yang diinginkan. seperti berikut:

# %%
# selecting rows by index
df.loc[1]
# Out:
# buah_(items)       Pisang
# harga_(price)        3000
# stok_(quantity)        20
# supplier            Garut
# Name: 1, dtype: object

# %% [markdown]
# Setelah itu kita melakukan hal yang sama ketika mengubah nama kolom yang menggunakan **.columns** dan meneruskan sebuah list yang berisi nama kolom yang baru. Namun dalam konteks ini terdapat beberapa perubahan pada fungsi yang digunakan yaitu **.loc**, berikut adalah contoh kodenya:

# %%
# add the new values in a list
df.loc[1] = ['Pisang', '4000', '10', 'Garut']
df
# Out:
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\1450610690.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '4000' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[1] = ['Pisang', '4000', '10', 'Garut']
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\1450610690.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '10' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[1] = ['Pisang', '4000', '10', 'Garut']
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         Apel          5000              10      Lembang
# 1       Pisang          4000              10        Garut
# 2        Jeruk          7000              15  Pangalengan
# 3       Anggur         10000               8        Bogor

# %% [markdown]
# Kita juga dapat memanfaatkan salah satu kemampuan fungsi **.loc**, yaitu melakukan seleksi terhadap kolom menggunakan nama kolomnya, sehingga kita dapat langsung memilih nilai yang ingin diubah. <br>Misalkan ternyata Apel sudah dipakai sebanyak 5 buah dan kita ingin mengubahnya pada dataset, kita dapat melakukannya dengan menggunakan **.loc** diikuti dengan index baris pisang yaitu 0 dan index kolom stok yaitu stok_(quantity), berikut adalah contoh kodenya:

# %%
# selecting a row based on index row and column's name, then adding a spesific new value
df.loc[0, 'stok_(quantity)'] = 5
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         Apel          5000               5      Lembang
# 1       Pisang          4000              10        Garut
# 2        Jeruk          7000              15  Pangalengan
# 3       Anggur         10000               8        Bogor

# %% [markdown]
# ### **2. Teknik Filtering**
# Pada teknik ini, kita menggunakan teknik filtering untuk melakukan seleksi terlebih dahulu, lalu setelah itu baru memasukkan nilai baru. Misalkan pada contoh diatas kita ingin mengganti harga anggur menjadi 9500. berikut adalah contoh kodenya:

# %%
filt = (df['buah_(items)']=='Anggur')
df[filt]['harga_(price)'] = 9500
# Out:
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\1731407875.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['harga_(price)'] = 9500

# %% [markdown]
# error diatas disebabkan kita tidak menggunakan **.loc** ketika hendak mengisi nilai baru, berikut adalah baris kode yang seharusnya:

# %%
filt = (df['buah_(items)']=='Anggur')
df.loc[filt, 'harga_(price)'] = 9500
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         Apel          5000               5      Lembang
# 1       Pisang          4000              10        Garut
# 2        Jeruk          7000              15  Pangalengan
# 3       Anggur          9500               8        Bogor

# %% [markdown]
# **Intinya**: untuk melakukan update nilai baru pada dataset, kita memerlukan fungsi **.loc**, jadi kedua teknik diatas hanyalah teknik filtering yang dimodifikasi agar dapat melakukan update nilai pada dataset.

# %% [markdown]
# ## Updating values for multiple rows
# Misalkan kita ingin mengubah nama masing-masing buah menjadi lowercase, untuk melakukannya kita dapat dengan memilih kolom yang ingin diubah, lalu menerapkan string method yang sesuai. berikut adalah contoh kodenya:

# %%
df['buah_(items)'].str.lower()
# Out:
# 0      apel
# 1    pisang
# 2     jeruk
# 3    anggur
# Name: buah_(items), dtype: object

# %% [markdown]
# Namun perubahan yang terjadi seperti diatas, hanya bersifat sementara yang artinya perubahan tidak tersimpan. berikut adalah contohnya:

# %%
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         Apel          5000               5      Lembang
# 1       Pisang          4000              10        Garut
# 2        Jeruk          7000              15  Pangalengan
# 3       Anggur          9500               8        Bogor

# %% [markdown]
# Agar perubahan dapat tersimpan, kita perlu melakukan *assigning* baris kode seperti diatas kedalam kolom yang ingin diubah. berikut adalah contoh baris kodenya:

# %%
df['buah_(items)'] = df['buah_(items)'].str.lower()
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         apel          5000               5      Lembang
# 1       pisang          4000              10        Garut
# 2        jeruk          7000              15  Pangalengan
# 3       anggur          9500               8        Bogor

# %% [markdown]
# Selain cara diatas, berikut adalah 4 method untuk melakukan memperbaharui beberapa baris kolom sekaligus:
# 1. apply
# 2. map
# 3. applymap
# 4. replace

# %% [markdown]
# ### .apply() dan .applymap()
# - **.apply()**: Digunakan untuk **mengaplikasikan fungsi ke setiap baris atau kolom** dalam DataFrame. Hasilnya bisa berupa DataFrame baru, Series baru, scalar, atau tipe data lain. Gunakan **.apply()** ketika Anda ingin **mengaplikasikan fungsi kompleks** atau melakukan **agregasi pada **baris/kolom** DataFrame.
# - **.applymap()**: Digunakan untuk **mengaplikasikan fungsi ke setiap elemen (nilai individual)** dalam DataFrame. Hasilnya selalu berupa DataFrame baru dengan struktur yang sama dengan DataFrame asli, hanya dengan nilai-nilainya yang diubah. Gunakan **.applymap()** ketika Anda ingin **mentransformasi nilai-nilai individual (misalnya, mengubah huruf besar ke kecil)** dalam DataFrame secara elementwise.
#
# berikut adalah contoh penerapannya:

# %%
df['buah_(items)'].apply(len)
# Out:
# 0    4
# 1    6
# 2    5
# 3    6
# Name: buah_(items), dtype: int64

# %% [markdown]
# **.apply()** memiliki fleksibilitas, selain menggunakan fungsi bawaan python/pandas seperti contoh diatas yang menggunakan fungsi len, kita juga dapat membuat fungsi kita sendiri seperti dibawah ini:

# %%
def upper (a):
    return a.upper()

# %%
df['buah_(items)'] = df['buah_(items)'].apply(upper)
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         APEL          5000               5      Lembang
# 1       PISANG          4000              10        Garut
# 2        JERUK          7000              15  Pangalengan
# 3       ANGGUR          9500               8        Bogor

# %% [markdown]
# jika fungsi yang akan kita masih sederhana, kita dapat membuatnya pada baris yang sama dengan menggunakan sebuah _**Lambda function**_ seperti berikut:

# %%
df['buah_(items)'] = df['buah_(items)'].apply(lambda x: x.lower())
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         apel          5000               5      Lembang
# 1       pisang          4000              10        Garut
# 2        jeruk          7000              15  Pangalengan
# 3       anggur          9500               8        Bogor

# %% [markdown]
# Namun kita harus familiar terlebih dahulu dengan apa itu Lambda function.

# %% [markdown]
# .apply dapat digunakan terhadap sebuah dataframe, misalnya pada baris kode dibawah akan menampilkan nama kolom beserta jumlah data untuk masing-masing kolomnya.

# %%
df.apply(len)
# Out:
# buah_(items)       4
# harga_(price)      4
# stok_(quantity)    4
# supplier           4
# dtype: int64

# %%
df[['buah_(items)','supplier']] = df[['buah_(items)','supplier']].applymap(lambda x: x.capitalize())
df
# Out:
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\527034894.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[['buah_(items)','supplier']] = df[['buah_(items)','supplier']].applymap(lambda x: x.capitalize())
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         Apel          5000               5      Lembang
# 1       Pisang          4000              10        Garut
# 2        Jeruk          7000              15  Pangalengan
# 3       Anggur          9500               8        Bogor

# %%
df[['buah_(items)','supplier']] = df[['buah_(items)','supplier']].applymap(lambda x: x.lower())
df
# Out:
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\2025723159.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[['buah_(items)','supplier']] = df[['buah_(items)','supplier']].applymap(lambda x: x.lower())
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         apel          5000               5      lembang
# 1       pisang          4000              10        garut
# 2        jeruk          7000              15  pangalengan
# 3       anggur          9500               8        bogor

# %%
df1 = df
df1
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0         apel          5000               5      lembang
# 1       pisang          4000              10        garut
# 2        jeruk          7000              15  pangalengan
# 3       anggur          9500               8        bogor

# %% [markdown]
# ### .map() dan .replace()
# **.map()** dan **.replace()** digunakan untuk mengubah sebuah nilai pada baris dan kolom target, untuk menggunakannya kita harus meneruskan sebuah dict yang berisi nilai baru. Namun untuk **.map()** jika jumlah dict tidak sesuai dengan jumlah kolom, fungsi ini akan mengisi kolom yang diabaikan dengan NaN (not a number). sebaliknya fungsi **.replace()** hanya akan mengganti nilai target saja tanpa mengubah nilai lain pada kolom dibaris target yang sama. berikut adalah contoh penggunaanya:

# %%
# mengubah apel menjadi jeruk
df1.loc[0] = df1.loc[0].map({'apel':'jeruk'})
df1
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0        jeruk           NaN             NaN          NaN
# 1       pisang          4000              10        garut
# 2        jeruk          7000              15  pangalengan
# 3       anggur          9500               8        bogor

# %%
# mengubah pisang jadi banana
df.loc[0] = df.loc[0].replace({'pisang' : 'banana'})
df
# Out:
#   buah_(items) harga_(price) stok_(quantity)     supplier
# 0        jeruk           NaN             NaN          NaN
# 1       pisang          4000              10        garut
# 2        jeruk          7000              15  pangalengan
# 3       anggur          9500               8        bogor

# %% [markdown]
# **Ingat!!!** untuk selalu melakukan assigning baris kode pada variabel target untuk memastikan perubahan tersimpan

# %% [markdown]
# # add/remove rows and columns
# Terkadang dalam melakukan cleaning atau analisis apapun, kita perlu menambahkan kolom atau baris baru.

# %% [markdown]
# ## columns

# %%
# Sample Data
data = {
  "Nama Depan": ["Budi", "Ani", "Cici", "Doni", "Evi"],
  "Nama Belakang": ["Setiawan", "Sugandi", "Kusumawati", "Hartono", "Maharani"],
  "Email": ["budisetiawan@gmail.com", "anisugadi@yahoo.com", "ciciks@hotmail.com", "donihartono@binus.ac.id", "evimaharani@unpad.ac.id"]
}
# Create a dataframe
df = pd.DataFrame(data)
df.head(2)
# Out:
#   Nama Depan Nama Belakang                   Email
# 0       Budi      Setiawan  budisetiawan@gmail.com
# 1        Ani       Sugandi     anisugadi@yahoo.com

# %% [markdown]
# Melakukan perubahan nama kolom agar *dot notasi* dapat digunakan

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#   Nama_Depan Nama_Belakang                    Email
# 0       Budi      Setiawan   budisetiawan@gmail.com
# 1        Ani       Sugandi      anisugadi@yahoo.com
# 2       Cici    Kusumawati       ciciks@hotmail.com
# 3       Doni       Hartono  donihartono@binus.ac.id
# 4        Evi      Maharani  evimaharani@unpad.ac.id

# %% [markdown]
# **Join columns** dilakukan dengan menggunakan operator (+) diantara kolom target, seperti berikut :
# > **df['kolom1'] + df['kolom2']**
#
# namun baris kode diatas akan membuat nilai pada kolom bersatu tanpa pemisah. jika ingin ada pemisah diantara nilai saat melakukan join columns, kita dapat melakukannya seperti berikut:
# > **df['kolom1'] + 'pemisah' + df['kolom2']**
#
# berikut adalah contoh kodenya:

# %%
df['Nama_Depan']+' '+df['Nama_Belakang']
# Out:
# 0      Budi Setiawan
# 1        Ani Sugandi
# 2    Cici Kusumawati
# 3       Doni Hartono
# 4       Evi Maharani
# dtype: object

# %% [markdown]
# Baris kode diatas akan mengembalikan sebuah Series, untuk memasukkan Series tersebut kedalam dataframe kita perlu melakukan *assigning* baris kode tersebut kedalam sebuah variabel yang nantinya akan menjadi kolom baru. Berikut adalah contoh kodenya:

# %%
df['Nama_Lengkap'] = df['Nama_Depan']+' '+df['Nama_Belakang']
df
# Out:
#   Nama_Depan Nama_Belakang                    Email     Nama_Lengkap
# 0       Budi      Setiawan   budisetiawan@gmail.com    Budi Setiawan
# 1        Ani       Sugandi      anisugadi@yahoo.com      Ani Sugandi
# 2       Cici    Kusumawati       ciciks@hotmail.com  Cici Kusumawati
# 3       Doni       Hartono  donihartono@binus.ac.id     Doni Hartono
# 4        Evi      Maharani  evimaharani@unpad.ac.id     Evi Maharani

# %% [markdown]
# **Drop column** merupakan cara untuk menghapus kolom yang diinginkan, untuk melakukannya kita perlu menggunakan fungsi **.drop** lalu meneruskan nama kolom target dalam sebuah list. berikut adalah contoh kodenya:

# %%
df.drop(columns=['Nama_Depan', 'Nama_Belakang'], inplace=True)
df
# Out:
#                      Email     Nama_Lengkap
# 0   budisetiawan@gmail.com    Budi Setiawan
# 1      anisugadi@yahoo.com      Ani Sugandi
# 2       ciciks@hotmail.com  Cici Kusumawati
# 3  donihartono@binus.ac.id     Doni Hartono
# 4  evimaharani@unpad.ac.id     Evi Maharani

# %% [markdown]
# karena **.drop()** merupakan sebuah method kita dapat menggunakan inplace=True untuk menyimpan perubahan yang dilakukan.

# %% [markdown]
# **Split columns** merupakan cara untuk memisahkan sebuah kolom, untuk melakukannya kita akan menggunakan sebuah fungsi string yaitu split setelah melakukan seleksi pada kolom target, berikut adalah contoh kodenya:

# %%
df['Nama_Lengkap'].str.split(' ')
# Out:
# 0      [Budi, Setiawan]
# 1        [Ani, Sugandi]
# 2    [Cici, Kusumawati]
# 3       [Doni, Hartono]
# 4       [Evi, Maharani]
# Name: Nama_Lengkap, dtype: object

# %% [markdown]
# Kita perlu **memperhatikan pemisah** apa yang digunakan pada kolom target, pemisah yang digunakan pada contoh ini adalah spasi " ".
#
# Baris kode diatas akan mengembalikan nilai dalam bentuk list dari kolom target untuk masing-masing baris, agar langsung menjadi sebuah dataframe kita harus menambahkan **expand=True** pada fungsi **.split** setelah pemisahnya. berikut adalah contoh kodenya:

# %%
df['Nama_Lengkap'].str.split(' ', expand=True)
# Out:
#       0           1
# 0  Budi    Setiawan
# 1   Ani     Sugandi
# 2  Cici  Kusumawati
# 3  Doni     Hartono
# 4   Evi    Maharani

# %% [markdown]
# **Assigning Columns** adalah teknik untuk memasukan kolom baru kedalam dataset. Pada baris kode diatas, perubahan yang dilakukan belum disimpan kedalam dataset. Untuk melakukannya kita perlu melakukan assigning baris kode tersebut kedalam sebuah variabel yang nantinya akan menjadi kolom baru.
#
# perlu diperhatikan jumlah kolom yang akan dimasukkan mempengaruhi variabelnya, berikut adalah contoh kodenya:

# %%
df[['Nama_Depan', 'Nama_Belakang']] = df['Nama_Lengkap'].str.split(' ', expand=True)
df
# Out:
#                      Email     Nama_Lengkap Nama_Depan Nama_Belakang
# 0   budisetiawan@gmail.com    Budi Setiawan       Budi      Setiawan
# 1      anisugadi@yahoo.com      Ani Sugandi        Ani       Sugandi
# 2       ciciks@hotmail.com  Cici Kusumawati       Cici    Kusumawati
# 3  donihartono@binus.ac.id     Doni Hartono       Doni       Hartono
# 4  evimaharani@unpad.ac.id     Evi Maharani        Evi      Maharani

# %% [markdown]
# ## Rows

# %% [markdown]
# **Adding new rows**, untuk menambahkan baris baru pada dataset kita menggunakan fungsi **.append()**. namun pada pandas versi terbaru, fungsi append digantikan dengan **._append()**. berikut adalah contoh kodenya:

# %%
df1 = df

# %%
df1._append({'Nama_Depan': 'Tony'}, ignore_index=True)
# Out:
#                      Email     Nama_Lengkap Nama_Depan Nama_Belakang
# 0   budisetiawan@gmail.com    Budi Setiawan       Budi      Setiawan
# 1      anisugadi@yahoo.com      Ani Sugandi        Ani       Sugandi
# 2       ciciks@hotmail.com  Cici Kusumawati       Cici    Kusumawati
# 3  donihartono@binus.ac.id     Doni Hartono       Doni       Hartono
# 4  evimaharani@unpad.ac.id     Evi Maharani        Evi      Maharani
# 5                      NaN              NaN       Tony           NaN

# %% [markdown]
# jika kita menambahkan baris baru namun hanya mengisi untuk beberapa kolom saja seperti contoh diatas, fungsi **._append()** akan mengisi kolom yang diabaikan dengan **NaN (missing values)**. Dalam menggunakan fungsi **._append()**, kita perlu memberi tahukan pandas untuk mengabaikan index dengan cara **ignore_index=True**.
#
# Kita dapat menambahkan baris baru dengan sebuah dataframe (mirip seperti join tabel), berikut adalah tahapannya:

# %%
# Sample Data
data = {
  "Nama_Depan": ["Steve", "Tony", ],
  "Nama_Belakang": ["Roger", "Stark"],
  "Email": ["ironman@avenger.com", "capt@avengercom"]
}
# Create a dataframe
df2 = pd.DataFrame(data)

# %%
df1._append(df2, ignore_index=True)
# Out:
#                      Email     Nama_Lengkap Nama_Depan Nama_Belakang
# 0   budisetiawan@gmail.com    Budi Setiawan       Budi      Setiawan
# 1      anisugadi@yahoo.com      Ani Sugandi        Ani       Sugandi
# 2       ciciks@hotmail.com  Cici Kusumawati       Cici    Kusumawati
# 3  donihartono@binus.ac.id     Doni Hartono       Doni       Hartono
# 4  evimaharani@unpad.ac.id     Evi Maharani        Evi      Maharani
# 5      ironman@avenger.com              NaN      Steve         Roger
# 6          capt@avengercom              NaN       Tony         Stark

# %% [markdown]
# Untuk menyimpan perubahan, kita harus melakukan assigning kode terhadap variabel dataset seperti berkut:

# %%
df1 = df1._append(df2, ignore_index=True)
df1
# Out:
#                      Email     Nama_Lengkap Nama_Depan Nama_Belakang
# 0   budisetiawan@gmail.com    Budi Setiawan       Budi      Setiawan
# 1      anisugadi@yahoo.com      Ani Sugandi        Ani       Sugandi
# 2       ciciks@hotmail.com  Cici Kusumawati       Cici    Kusumawati
# 3  donihartono@binus.ac.id     Doni Hartono       Doni       Hartono
# 4  evimaharani@unpad.ac.id     Evi Maharani        Evi      Maharani
# 5      ironman@avenger.com              NaN      Steve         Roger
# 6          capt@avengercom              NaN       Tony         Stark

# %% [markdown]
# **Drop rows** merupakan cara untuk menghapus baris didalam dataset. Sama halnya seperti menghapus kolom, yaitu dengan menggunakan fungsi **.drop()**. Yang membedakannya adalah, kita menambahkan **index='index barisnya'**. berikut adalah contoh kodenya:

# %%
df1.drop(index=6)
# Out:
#                      Email     Nama_Lengkap Nama_Depan Nama_Belakang
# 0   budisetiawan@gmail.com    Budi Setiawan       Budi      Setiawan
# 1      anisugadi@yahoo.com      Ani Sugandi        Ani       Sugandi
# 2       ciciks@hotmail.com  Cici Kusumawati       Cici    Kusumawati
# 3  donihartono@binus.ac.id     Doni Hartono       Doni       Hartono
# 4  evimaharani@unpad.ac.id     Evi Maharani        Evi      Maharani
# 5      ironman@avenger.com              NaN      Steve         Roger

# %% [markdown]
# Selain langsung menggunakan index baris target, kita juga dapat menggunakan teknik filtering untuk menghapus kolom. caranya adalah kita membuat kondisi/kriteria filter terlebih dahulu, agar kode lebih mudah dibaca lakukan assigning kondisi/kriteria yang menjadi filter tersebut kedalam sebuah variabel (disini nama variabel yang digunakan adalah **filt**), selanjutnya gunakan fungsi **.drop** dan teruskan filter tersebut menggunakan fungsi  **.loc** yang diikuti oleh  **.index** kedalam parameter index di fungsi drop.
#
# Misalkan kita ingin menghapus baris yang emailnya tidak diakhiri oleh .com, berikut adalah contoh kodenya:

# %%
# create a filter
filt = ~df1['Email'].str.contains('com')

# drop rows based on filter then update the dataset
df1 = df1.drop(index=df1.loc[filt].index)

# showing the result
df1
# Out:
#                     Email     Nama_Lengkap Nama_Depan Nama_Belakang
# 0  budisetiawan@gmail.com    Budi Setiawan       Budi      Setiawan
# 1     anisugadi@yahoo.com      Ani Sugandi        Ani       Sugandi
# 2      ciciks@hotmail.com  Cici Kusumawati       Cici    Kusumawati
# 5     ironman@avenger.com              NaN      Steve         Roger
# 6         capt@avengercom              NaN       Tony         Stark

# %% [markdown]
# .index memberi tahu pandas bahwa untuk menjadikan hasil filter sebagai index, agar dapat dipahami oleh fungsi **.drop(index=)**

# %% [markdown]
# # Sorting
# Sorting values merupakan langkah penting dalam analisis data yang dapat membantu meningkatkan pemahaman, efisiensi, dan akurasi analisis.

# %%
df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\661450976.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
# ...

# %% [markdown]
# **Sorting values** pada dasarnya mengurutkan dataset berdasarkan salah satu kolom, dalam melakukan sorting pada nilai kita memerlukan inplace=True untuk memastikan bahwa hasil sorting sesuai dengan yang kita inginkan. Berikut merupakan contoh melakukan sorting nilai berdasarkan kolom Country, dan menampilkan 50 teratas.

# %%
df.sort_values('Country', inplace=True)

# %%
df['Country'].head(50)
# Out:
# 39018    Afghanistan
# 62723    Afghanistan
# 85185    Afghanistan
# 50437    Afghanistan
# 88340    Afghanistan
# 88735    Afghanistan
# 6391     Afghanistan
# 39754    Afghanistan
# 88181    Afghanistan
# 48122    Afghanistan
# 10697    Afghanistan
# 62124    Afghanistan
# 49377    Afghanistan
# 32971    Afghanistan
# 60559    Afghanistan
# 85827    Afghanistan
# 88033    Afghanistan
# 28470    Afghanistan
# 719      Afghanistan
# 26189    Afghanistan
# 86394    Afghanistan
# 85293    Afghanistan
# 7056     Afghanistan
# 7323     Afghanistan
# 86551    Afghanistan
# 58390    Afghanistan
# 73920    Afghanistan
# 28877    Afghanistan
# 51525    Afghanistan
# 45562    Afghanistan
# 46807    Afghanistan
# 44123    Afghanistan
# 22327    Afghanistan
# 8112     Afghanistan
# 80423    Afghanistan
# 59184    Afghanistan
# 60185    Afghanistan
# 37571    Afghanistan
# 29560    Afghanistan
# 42832    Afghanistan
# 12253    Afghanistan
# 58082    Afghanistan
# 61770    Afghanistan
# ...

# %% [markdown]
# berikut adalah ketika kita menambahkan satu kolom lagi untuk ikut ditampilkan, terlihat meskipun kolom Country sudah sesuai urutan abjad, namun kolom ConvertedComp masih berantakan. Untuk memudahkan analisis, kita dapat menambahkan satu kondisi sorting baru jika kondisi sorting yang pertama kurang jelas.

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#            Country  ConvertedComp
# 39018  Afghanistan        19152.0
# 62723  Afghanistan      1000000.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 26189  Afghanistan            NaN
# 86394  Afghanistan            NaN
# 85293  Afghanistan            NaN
# 7056   Afghanistan        14364.0
# 7323   Afghanistan            NaN
# 86551  Afghanistan            NaN
# 58390  Afghanistan            NaN
# ...

# %% [markdown]
# Berikut ini merupakan **sorting nilai berdasarkan 2 kondisi sorting**, kondisi sorting yang pertama adalah berdasarkan kolom **Country** dengan perintah **ascending = True (sorted by smallest to largest)** sementara kondisi sorting yang kedua berdasarkan kolom **ConvertedComp** dengan perintah **ascending = False (sorted by largest to smallest)**.

# %%
df.sort_values(['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country', 'ConvertedComp']].head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 26189  Afghanistan            NaN
# ...

# %% [markdown]
# Melakukan sorting dengan **2 kondisi sort by, dapat dilakukan jika nilai kolom pada salah satu kondisi sama persis** (pada contoh diatas kolom **Country** memiliki jenis nilai **nominal/label**). Pada contoh diatas akan lebih mudah untuk mengetahui pendapatan/ConvertedComp dari yang tertinggi hingga terendah untuk masing-masing negara.

# %% [markdown]
# # Group by dan Agregate

# %%
df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
skema_df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_schema.csv')

pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\794314355.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_public.csv')
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\794314355.py:2: SyntaxWarning: invalid escape sequence '\D'
#   skema_df = pd.read_csv('D:\DataScience\Pandas\Data\stack-overflow-developer-survey-2019\survey_results_schema.csv')

# %%
df.set_index('Respondent', inplace=True)
skema_df.set_index('Column', inplace=True)

# %% [markdown]
# ## Aggregate

# %%
df['ConvertedComp']
# Out:
# Respondent
# 1            NaN
# 2            NaN
# 3         8820.0
# 4        61000.0
# 5            NaN
#           ...
# 88377        NaN
# 88601        NaN
# 88802        NaN
# 88816        NaN
# 88863        NaN
# Name: ConvertedComp, Length: 88883, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.describe()
# Out:
#           CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04   5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11   1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13   2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00   0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04   2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04   5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05   1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16   2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['ConvertedComp'].count()
# Out:
# 55823

# %%
df['Hobbyist'].value_counts()
# Out:
# Hobbyist
# Yes    71257
# No     17626
# Name: count, dtype: int64

# %%
df['SocialMedia']
# Out:
# Respondent
# 1          Twitter
# 2        Instagram
# 3           Reddit
# 4           Reddit
# 5         Facebook
#            ...
# 88377      YouTube
# 88601          NaN
# 88802          NaN
# 88816          NaN
# 88863     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['SocialMedia'].value_counts()
# Out:
# SocialMedia
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: count, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True)
# Out:
# SocialMedia
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: proportion, dtype: float64

# %%
df.groupby(['Country'])

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
# C:\Users\505\AppData\Local\Temp\ipykernel_5568\1353200628.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('United States')
#                                 MainBranch Hobbyist  \
# Respondent
# 4           I am a developer by profession       No
# 13          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 23          I am a developer by profession      Yes
# 26          I am a developer by profession      Yes
# ...                                    ...      ...
# 78292                                  NaN       No
# 82717                                  NaN       No
# 83397                                  NaN      Yes
# 85642                                  NaN       No
# 88282                                  NaN      Yes
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['SocialMedia'].value_counts()
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: count, dtype: int64

# %%
country_grp['SocialMedia'].value_counts(normalize=True).loc['China']
# Out:
# SocialMedia
# WeChat 微信                   0.670549
# YouTube                     0.088186
# Weibo 新浪微博                  0.069884
# I don't use social media    0.044925
# Twitter                     0.044925
# Reddit                      0.019967
# LinkedIn                    0.018303
# Facebook                    0.013311
# Instagram                   0.011647
# Youku Tudou 优酷              0.011647
# WhatsApp                    0.004992
# VK ВКонта́кте               0.001664
# Name: proportion, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Indonesia']
# Out:
# 7740.0

# %%
country_grp['ConvertedComp'].agg(['median', 'mean']).loc['Indonesia']
# Out:
# median     7740.000000
# mean      30986.410377
# Name: Indonesia, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[163], line 1
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# File c:\Users\505\miniconda3\envs\tutorial_env\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.__getattr__(self, attr)
#    1360 if attr in self.obj:
#    1361     return self[attr]
# -> 1363 raise AttributeError(
#    1364     f"'{type(self).__name__}' object has no attribute '{attr}'"
#    1365 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States        20949
# India                 9061
# Germany               5866
# United Kingdom        5737
# Canada                3395
#                      ...
# Tonga                    1
# Timor-Leste              1
# North Korea              1
# Brunei Darussalam        1
# Chad                     1
# Name: count, Length: 179, dtype: int64

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
type(country_respondents)
# Out:
# pandas.core.series.Series

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns', sort=False)
python_df.reset_index()
# Out:
#                Country  count  LanguageWorkedWith
# 0        United States  20949               10083
# 1                India   9061                3105
# 2              Germany   5866                2451
# 3       United Kingdom   5737                2384
# 4               Canada   3395                1558
# ..                 ...    ...                 ...
# 174              Tonga      1                   0
# 175        Timor-Leste      1                   1
# 176        North Korea      1                   0
# 177  Brunei Darussalam      1                   0
# 178               Chad      1                   0
#
# [179 rows x 3 columns]

# %%
python_df.rename(columns={'count':'NumRespondent', 'LanguageWorkedWith':'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                    NumRespondent  NumKnowsPython
# Country
# United States              20949           10083
# India                       9061            3105
# Germany                     5866            2451
# United Kingdom              5737            2384
# Canada                      3395            1558
# ...                          ...             ...
# Tonga                          1               0
# Timor-Leste                    1               1
# North Korea                    1               0
# Brunei Darussalam              1               0
# Chad                           1               0
#
# [179 rows x 2 columns]

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondent']) * 100
python_df
# Out:
#                    NumRespondent  NumKnowsPython  PctKnowsPython
# Country
# United States              20949           10083       48.131176
# India                       9061            3105       34.267741
# Germany                     5866            2451       41.783157
# United Kingdom              5737            2384       41.554820
# Canada                      3395            1558       45.891016
# ...                          ...             ...             ...
# Tonga                          1               0        0.000000
# Timor-Leste                    1               1      100.000000
# North Korea                    1               0        0.000000
# Brunei Darussalam              1               0        0.000000
# Chad                           1               0        0.000000
#
# [179 rows x 3 columns]

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.loc[['Indonesia', 'Japan']]
# Out:
#            NumRespondent  NumKnowsPython  PctKnowsPython
# Country
# Indonesia            507             148       29.191321
# Japan                391             182       46.547315
